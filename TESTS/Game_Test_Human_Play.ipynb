# %%
# !pip install git+https://github.com/Shmuma/TextWorld > /dev/null 2>&1
# !pip install ptan > /dev/null 2>&1
# !pip3 install torch torchvision > /dev/null 2>&1

# Juggling around colab requirement
# !pip uninstall -y prompt-toolkit > /dev/null 2>&1
# !pip install prompt-toolkit==1.0.16
# DO NOT FORGET to restart runtime as suggested
# Out:
# Collecting prompt-toolkit==1.0.16
#   Using cached https://files.pythonhosted.org/packages/57/a8/a151b6c61718eabe6b4672b6aa760b734989316d62ec1ba4996765e602d4/prompt_toolkit-1.0.16-py3-none-any.whl
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit==1.0.16) (0.1.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit==1.0.16) (1.12.0)
# ERROR: textworld 1.1.1 has requirement prompt-toolkit<2.1.0,>=2.0.0, but you'll have prompt-toolkit 1.0.16 which is incompatible.
# Installing collected packages: prompt-toolkit
# Successfully installed prompt-toolkit-1.0.16

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3c033f8-b15e-4a08-9c96-d515cf45e6c2" name="files[]" multiple disabled />
#      <output id="result-a3c033f8-b15e-4a08-9c96-d515cf45e6c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving etsit.ulx to etsit.ulx
# Saving etsit.json to etsit.json

# %%
import textworld
textworld.play("etsit.ulx")
# Out:
#                     ________  ________  __    __  ________
#                    |        \|        \|  \  |  \|        \
#                     \$$$$$$$$| $$$$$$$$| $$  | $$ \$$$$$$$$
#                       | $$   | $$__     \$$\/  $$   | $$
#                       | $$   | $$  \     >$$  $$    | $$
#                       | $$   | $$$$$    /  $$$$\    | $$
#                       | $$   | $$_____ |  $$ \$$\   | $$
#                       | $$   | $$     \| $$  | $$   | $$
#                        \$$    \$$$$$$$$ \$$   \$$    \$$
#               __       __   ______   _______   __        _______
#              |  \  _  |  \ /      \ |       \ |  \      |       \
#              | $$ / \ | $$|  $$$$$$\| $$$$$$$\| $$      | $$$$$$$\
#              | $$/  $\| $$| $$  | $$| $$__| $$| $$      | $$  | $$
#              | $$  $$$\ $$| $$  | $$| $$    $$| $$      | $$  | $$
#              | $$ $$\$$\$$| $$  | $$| $$$$$$$\| $$      | $$  | $$
#              | $$$$  \$$$$| $$__/ $$| $$  | $$| $$_____ | $$__/ $$
#              | $$$    \$$$ \$$    $$| $$  | $$| $$     \| $$    $$
#               \$$      \$$  \$$$$$$  \$$   \$$ \$$$$$$$$ \$$$$$$$
#
# You are now playing a fast paced round of TextWorld! Here is how to play! First
# of all, you could, like, head west. And then, recover the Coffee Shop Key from
# the Table. And then, move east. And then, insert the Coffee Shop Key into the
# Coffee shop door's lock to unlock it. Then, ensure that the Coffee shop door is
# open. And then, make an effort to go to the east. Next, look and see that the
# microwave inside the Coffee shop is ajar. After that, take the Apple from the
# microwave within the Coffee shop. After taking the Apple, eat the Apple. Once
# that's all handled, you can stop!
#
# -= Hall =-
# You arrive in a Hall. A typical kind of place. You begin to take stock of what's
# here.
#
#
#
# You need an unblocked exit? You should try going east. You need an unblocked
# exit? You should try going west.
#
# There is a Welcome on the floor.
#
# > go east
# You have to open the Coffee shop door first.
#
# > go west
#
# -= Library =-
# This is the ETSIT library!. There is a table. There is a key on the table.
#
# There is a Hint on the floor.
#
# > take key
# You take the Coffee Shop Key from the Table.
#
# > go east
#
# -= Hall =-
# You arrive in a Hall. A typical kind of place. You begin to take stock of what's
# here.
#
#
#
# You need an unblocked exit? You should try going east. You need an unblocked
# exit? You should try going west.
#
# There is a Welcome on the floor.
#
# > unlock door
# (with the Coffee Shop Key)
# You unlock Coffee shop door.
#
# > open door
# You open Coffee shop door.
#
# > go east
#
# -= Coffee Shop =-
# This is the ETSIT coffee shop, ther is a microwave, it looks closed.
#
# > open microwave
# You open the microwave, revealing an Apple.
#
# > take apple
# You take the Apple from the microwave.
#
# > eat apple
# You eat the Apple. Not bad.
#
#
# Your score has just gone up by one point.
#
#
#                                *** The End ***
#
# You scored 1 out of a possible 1, in 11 turn(s).
#
#
# Would you like to RESTART, RESTORE a saved game, QUIT or UNDO the last command?
# >
#
# Done after 10 steps. Score 1/1.
